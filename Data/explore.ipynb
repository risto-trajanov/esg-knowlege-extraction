# %%
import pandas as pd

# %%
df = pd.read_csv('./data/news/oil_news.csv')

# %%
df
# Out:
#       Unnamed: 0                                              title  \
# 0              0  N.J. sues Exxon, Chevron over damages related ...
# 1              1  Exxon, Shell and Chevron Sued by NJ Over Clima...
# 2              2  NJ sues oil, gas firms, trade group over clima...
# 3              3  Adam McKay’s Scathing Fake Chevron Ad Blasting...
# 4              4  Chevron's shareholders vote against emissions ...
# ...          ...                                                ...
# 2338           1  How Does Tesla Get A Worse ESG Score Than 2 Oi...
# 2339           2  Fitch Affirms Shell at 'AA-'; Stable Outlook -...
# 2340           3  ESG Is Not Impact Investing and Impact Investi...
# 2341           4  What is Sustainable Investing? Guide for Febru...
# 2342           5  Renewed focus on Africa in global oil and gas ...
#
#                                                     url  language  \
# 0     https://news.google.com/rss/articles/CBMibmh0d...       NaN
# ...

# %%
df['query'].value_counts()
# Out:
# climate change           271
# chemicals                243
# data protection          176
# carbon emissions         168
# data privacy             160
# carbon neutral           143
# community                130
# solar power              124
# working condition        123
# water pollution          120
# lawsuit                  103
# plastics                  81
# low carbon                74
# health care               62
# air pollution             59
# human rights              43
# greenwashing              39
# donation                  37
# labor standards           32
# lobbying                  30
# corruption                28
# charity                   19
# diversity                 16
# esg                       16
# esg regulations           15
# volunteer                 11
# bribery                    6
# customer satisfaction      6
# illegal                    3
# gender                     3
# reforestation              2
# Name: query, dtype: int64
