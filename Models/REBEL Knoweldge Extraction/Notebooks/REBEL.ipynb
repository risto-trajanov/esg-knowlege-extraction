# %% [markdown]
# # Install the relevant libraries

# %%
# !pip install transformers wikipedia newspaper3k GoogleNews pyvis -qq

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import math
import torch
import wikipedia
from newspaper import Article, ArticleException
from GoogleNews import GoogleNews
import IPython
from pyvis.network import Network

# %% [markdown]
# # Load the REBEL model

# %%
# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/344 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %% [markdown]
# # Load Sentiment Model

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="TrajanovRisto/bert-esg")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/348 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
def get_sentiment(text):
    sentence_class = {}
    for id, sent in enumerate(text.split('. ')):
      if len(sent) > 512:
        sent = sent[:512]
      sentence_class[id] = classifier(sent)
    return sentence_class

# %% [markdown]
# # Model output to realtions

# %%
def extract_relations_from_model_output(text):
    relations = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    text_replaced = text.replace("<s>", "").replace("<pad>", "").replace("</s>", "")
    for token in text_replaced.split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                relations.append({
                    'head': subject.strip(),
                    'type': relation.strip(),
                    'tail': object_.strip()
                })
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        relations.append({
            'head': subject.strip(),
            'type': relation.strip(),
            'tail': object_.strip()
        })
    return relations

# %% [markdown]
# # Split spans: from long text to KB

# %%
class KB():
    def __init__(self):
        self.relations = []
        self.entities = {}

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r1):
        r2 = [r for r in self.relations
              if self.are_relations_equal(r1, r)][0]
        spans_to_add = [span for span in r1["meta"]["spans"]
                        if span not in r2["meta"]["spans"]]
        r2["meta"]["spans"] += spans_to_add

    def add_entity(self, e):
        self.entities[e] = {'url': ''}

    def add_relation(self, r):
        entities = [r["head"], r["tail"]]

        for e in entities:
            self.add_entity(e)
        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self):
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")

# %%
def from_text_to_kb(text, span_length=128, verbose=False, num_return_sequences=3):
    # tokenize whole text
    inputs = tokenizer([text], return_tensors="pt")

    # compute span boundaries
    num_tokens = len(inputs["input_ids"][0])
    if verbose:
        print(f"Input has {num_tokens} tokens")
    num_spans = math.ceil(num_tokens / span_length)
    if verbose:
        print(f"Input has {num_spans} spans")
    overlap = math.ceil((num_spans * span_length - num_tokens) / 
                        max(num_spans - 1, 1))
    spans_boundaries = []
    start = 0
    for i in range(num_spans):
        spans_boundaries.append([start + span_length * i,
                                 start + span_length * (i + 1)])
        start -= overlap
    if verbose:
        print(f"Span boundaries are {spans_boundaries}")

    # transform input with spans
    tensor_ids = [inputs["input_ids"][0][boundary[0]:boundary[1]]
                  for boundary in spans_boundaries]
    tensor_masks = [inputs["attention_mask"][0][boundary[0]:boundary[1]]
                    for boundary in spans_boundaries]
    inputs = {
        "input_ids": torch.stack(tensor_ids),
        "attention_mask": torch.stack(tensor_masks)
    }

    # generate relations
    num_return_sequences = 3
    gen_kwargs = {
        "max_length": 256,
        "length_penalty": 0,
        "num_beams": num_return_sequences,
        "num_return_sequences": num_return_sequences
    }
    generated_tokens = model.generate(
        **inputs,
        **gen_kwargs,
    )

    # decode relations
    decoded_preds = tokenizer.batch_decode(generated_tokens,
                                           skip_special_tokens=False)


    id_sentence = {id:sent for id, sent in enumerate(text.split('. '))}
    # sentence_entities, entity_ner = get_ner(text)
    sentence_class = get_sentiment(text)
    # create kb
    kb = KB()
    i = 0
    for sentence_pred in decoded_preds:
        current_span_index = i // num_return_sequences
        relations = extract_relations_from_model_output(sentence_pred)
        for relation in relations:
            for id, sent in id_sentence.items():
              if relation['head'] in sent and relation['tail'] in sent:
                relation['sentiment'] = sentence_class[id][0]['label']
            relation["meta"] = {
                "spans": [spans_boundaries[current_span_index]]
            }
            kb.add_relation(relation)
        i += 1

    return kb

# %% [markdown]
# # Filter and normalize entities with Wikipedia
#
# - remove all entities that doesn't have a page on Wikipedia
# - merge entities if they have the same wikipedia page

# %%
text = """
As evidence of the severe impacts from climate change mounts, policy makers, companies, and financial bodies are increasingly focused on the economic impacts1 from driving greenhouse gas (GHG) emissions to well-below 2 degrees Celsius below pre-industrial levels (including 1.5° C ambitions), as outlined in the Paris Agreement.
This focus has led many Chevron peers (including BP, Eni, Equinor, Repsol, Royal Dutch Shell, and Total) to commit to major GHG reductions, including setting “net zero emission” goals by 2050.2,3
Investors are also calling for high-emitting companies to test their financial assumptions and resiliency against substantial reduced-demand climate scenarios,4 and to provide investors insights about the potential impact on their financial statements.5,6,7
As of December 2020, Chevron Corporation had neither committed to net-zero emissions by 2050 across its value chain, nor disclosed how its financial assumptions would change from doing so.
In contrast, the audit reports for other high GHG-emitting companies clearly discussed this connection:
BP: how climate change and a global energy transition impacted the capitalization of exploration and appraisal costs and risks that oil and gas price assumptions could lead to financial misstatements;
Shell: how long-term price assumptions impacted by climate change could affect asset values and impairment estimates;
National Grid: noted estimates inconsistent with 2050 “net zero” commitments.
Additionally, in 2020, BP, Shell and Total reviewed their 2019 financial accounting practices in light of the accelerating low-carbon energy transition. All three subsequently adjusted critical accounting assumptions, resulting in material impairments, and disclosed how climate change affected the adjustments.
In October 2020, the International Energy Agency (IEA) issued a new “Net Zero 2050” scenario which describes what it would mean for the energy sector globally to reach net-zero GHG emissions by 2050.
This more aggressive global action to curtail climate change is consistent with a 1.5°C temperature increase globally.8
RESOLVED: Shareholders request that Chevron’s Board of Directors issue an audited report to shareholders on whether and how a significant reduction in fossil fuel demand, envisioned in the IEA Net Zero 2050 scenario, would affect its financial position and underlying assumptions. The Board should summarize its findings to shareholders by January 31, 2022, and the report should be completed at reasonable cost and omitting proprietary information.
Proponents recommend that in issuing the report, the company take account of information on:
Assumptions, costs, estimates, and valuations that may be materially impacted; and
The potential for widespread adoption of net-zero goals by governments and peers.9
Proponents recommend that the report be supported by reasonable assurance from an independent auditor.
"""

kb_proposal = from_text_to_kb(text)

# %%
kb_proposal.print()
# Out:
# Relations:
#   {'head': 'severe impacts from climate change', 'type': 'has effect', 'tail': 'economic impacts1', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'economic impacts1', 'type': 'has cause', 'tail': 'severe impacts from climate change', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'severe impacts from climate change', 'type': 'facet of', 'tail': 'Paris Agreement', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'BP', 'type': 'significant event', 'tail': 'global energy transition', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[112, 240]]}}
#   {'head': 'reduced-demand', 'type': 'facet of', 'tail': 'climate change', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[112, 240]]}}
#   {'head': 'BP', 'type': 'participant in', 'tail': 'global energy transition', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[112, 240]]}}
#   {'head': 'accelerating low-carbon energy transition', 'type': 'facet of', 'tail': 'global energy transition', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[224, 352]]}}
#   {'head': 'accelerating low-carbon energy transition', 'type': 'facet of', 'tail': 'climate change', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[224, 352]]}}
#   {'head': 'accelerating low-carbon energy transition', 'type': 'point in time', 'tail': '2020', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[224, 352]]}}
#   {'head': 'IEA Net Zero 2050 scenario', 'type': 'publisher', 'tail': 'International Energy Agency', 'sentiment': 'Governance Positive', 'meta': {'spans': [[336, 464]]}}
#   {'head': 'IEA Net Zero 2050 scenario', 'type': 'author', 'tail': 'International Energy Agency', 'sentiment': 'Governance Positive', 'meta': {'spans': [[336, 464]]}}
#   {'head': 'IEA Net Zero 2050', 'type': 'publisher', 'tail': 'International Energy Agency', 'sentiment': 'Governance Positive', 'meta': {'spans': [[336, 464]]}}
#   {'head': 'Net Zero 2050', 'type': 'author', 'tail': 'IEA', 'sentiment': 'Governance Positive', 'meta': {'spans': [[448, 576]]}}
#   {'head': 'net-zero goals', 'type': 'creator', 'tail': 'IEA', 'meta': {'spans': [[448, 576]]}}
#   {'head': 'IEA Net Zero 2050', 'type': 'instance of', 'tail': 'net-zero goals', 'meta': {'spans': [[448, 576]]}}

# %%
save_network_html(kb_proposal, filename='chevron_proposal.html')
IPython.display.HTML(filename=filename)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# chevron_proposal.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 700px;
#                  height: 700px;
#                  background-color: #eeeeee;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#              #loadingBar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width: 700px;
#                  height: 700px;
#                  background-color:rgba(200,200,200,0.8);
#                  -webkit-transition: all 0.5s ease;
#                  -moz-transition: all 0.5s ease;
#                  -ms-transition: all 0.5s ease;
#                  -o-transition: all 0.5s ease;
#                  transition: all 0.5s ease;
#                  opacity:1;
#              }
#
#              #bar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width:20px;
#                  height:20px;
#                  margin:auto auto auto auto;
#                  border-radius:11px;
#                  border:2px solid rgba(30,30,30,0.05);
#                  background: rgb(0, 173, 246); /* Old browsers */
#                  box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#              }
#
#              #border {
#                  position:absolute;
#                  top:10px;
#                  left:10px;
#                  width:500px;
#                  height:23px;
#                  margin:auto auto auto auto;
#                  box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#                  border-radius:10px;
#              }
#
#              #text {
#                  position:absolute;
#                  top:8px;
#                  left:530px;
#                  width:30px;
#                  height:50px;
#                  margin:auto auto auto auto;
#                  font-size:22px;
#                  color: #000000;
#              }
#
#              div.outerBorder {
#                  position:relative;
#                  top:400px;
#                  width:600px;
#                  height:44px;
#                  margin:auto auto auto auto;
#                  border:8px solid rgba(0,0,0,0.1);
#                  background: rgb(252,252,252); /* Old browsers */
#                  background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#                  background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#                  background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#                  background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#                  background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#                  background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#                  filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#                  border-radius:72px;
#                  box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#              }
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#             <div id="loadingBar">
#               <div class="outerBorder">
#                 <div id="text">0%</div>
#                 <div id="border">
#                   <div id="bar"></div>
#                 </div>
#               </div>
#             </div>
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#A699B0", "id": "Equinor", "label": "Equinor", "shape": "circle"}, {"color": "#A699B0", "id": "Norway", "label": "Norway", "shape": "circle"}, {"color": "#A699B0", "id": "Repsol", "label": "Repsol", "shape": "circle"}, {"color": "#A699B0", "id": "Spain", "label": "Spain", "shape": "circle"}, {"color": "#A699B0", "id": "Norway\u0027s", "label": "Norway\u0027s", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage", "label": "carbon capture and storage", "shape": "circle"}, {"color": "#A699B0", "id": "carbon", "label": "carbon", "shape": "circle"}, {"color": "#A699B0", "id": "oil", "label": "oil", "shape": "circle"}, {"color": "#A699B0", "id": "energy", "label": "energy", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage technology", "label": "carbon capture and storage technology", "shape": "circle"}, {"color": "#A699B0", "id": "ConocoP", "label": "ConocoP", "shape": "circle"}, {"color": "#A699B0", "id": "Chevron", "label": "Chevron", "shape": "circle"}, {"color": "#A699B0", "id": "methane", "label": "methane", "shape": "circle"}, {"color": "#A699B0", "id": "Exxon", "label": "Exxon", "shape": "circle"}, {"color": "#A699B0", "id": "GHG", "label": "GHG", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity", "label": "carbon intensity", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity vs 2016", "label": "carbon intensity vs 2016", "shape": "circle"}, {"color": "#A699B0", "id": "2016", "label": "2016", "shape": "circle"}, {"color": "#A699B0", "id": "Shell", "label": "Shell", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage capacity", "label": "carbon capture and storage capacity", "shape": "circle"}, {"color": "#A699B0", "id": "oil equivalent", "label": "oil equivalent", "shape": "circle"}, {"color": "#A699B0", "id": "barrels

# %%
text = """
Chevron believes the future of energy is lower carbon and aims to equip stockholders with data and facts so that they can make informed choices as the world moves toward the global net-zero ambitions of the Paris agreement. In March 2021, the Company published its third Climate Change Resilience Report aligned with the Task Force for Climate-related Financial Disclosures. The report outlines Chevron’s approach to the energy transition, including testing the resiliency of Chevron’s portfolio against the International Energy Agency’s Sustainable Development Scenario (“SDS”) and Net Zero Scenario.
At its Investor Day on March 9, 2021, Chevron outlined the steps it is taking, and the challenges it faces, in working toward a net-zero future. This includes changes in portfolio, execution of projects identified through marginal abatement cost curves, and the policy, innovations, and offsets necessary to achieve net-zero.
Chevron uses long-term energy demand scenarios and a range of commodity prices to test its portfolio, guide investment strategies, and evaluate business risks to ensure it can deliver results under a range of potential futures. Chevron analyzes how various factors may combine to create alternative scenarios to stress-test its portfolio and integrate learnings into its decision making to remain competitive and resilient under multiple scenarios.
For longer-term scenarios, Chevron routinely uses external views to both inform and challenge its internal analysis. Chevron’s analysis includes scenarios forecasting emissions pathways that keep global warming to well below 2o C above pre-industrial levels, as well as scenarios forecasting net-zero emissions by 2050.1 One example of a lower carbon scenario tested against Chevron’s portfolio is the SDS. The SDS outlines one potential path to 2040 that achieves the objectives of recent clean energy policies, including the Paris Agreement, keeping global average temperatures well below 2o C above pre-industrial levels and putting the world on track to achieve net-zero emissions by 2070.
In 2020, more than 60 percent of Chevron’s total Scope 1 and Scope 2 equity GHG emissions were in regions with existing or developing carbon pricing policies.2 Chevron uses carbon prices and derived carbon costs in business planning, investment decisions, impairment reviews, reserves calculations, and assessment of carbon reduction opportunities. We believe that the Company’s portfolio is resilient, and that its governance structure, risk management, strategy, actions, and asset mix enable it to be flexible in response to potential changes in supply and demand, even in lower carbon scenarios.
The Company leverages its capabilities, assets, and expertise to focus on these three action areas that aim to deliver measurable progress: (1) lower carbon intensity cost efficiently, (2) increase renewables and offsets in support of our own business, and (3) invest in low-carbon technologies to enable commercial solutions.
Chevron’s employees are proud of their role in providing affordable, reliable, and ever-cleaner energy that people around the world depend on every day.
Given Chevron’s current disclosures and robust strategy, planning, and risk management processes, your Board believes that the requested report is unnecessary.
Therefore, your Board recommends that you vote AGAINST this proposal.
"""

kb_response = from_text_to_kb(text)
kb_response.print()
# Out:
# Relations:
#   {'head': 'Sustainable Development Scenario', 'type': 'publisher', 'tail': 'International Energy Agency', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'Sustainable Development Scenario', 'type': 'creator', 'tail': 'International Energy Agency', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'Sustainable Development Scenario', 'type': 'author', 'tail': 'International Energy Agency', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[0, 128]]}}
#   {'head': 'Sustainable Development Scenario', 'type': 'facet of', 'tail': 'net-zero future', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[106, 234]]}}
#   {'head': 'Sustainable Development Scenario', 'type': 'facet of', 'tail': 'net-zero', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[106, 234]]}}
#   {'head': 'Sustainable Development Scenario', 'type': 'part of', 'tail': 'net-zero future', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[106, 234]]}}
#   {'head': 'net-zero emissions by 2050', 'type': 'point in time', 'tail': '2050', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[212, 340]]}}
#   {'head': 'lower carbon scenario', 'type': 'subclass of', 'tail': 'emissions pathways', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[212, 340]]}}
#   {'head': 'lower carbon scenario', 'type': 'instance of', 'tail': 'emissions pathways', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[212, 340]]}}
#   {'head': 'Paris Agreement', 'type': 'main subject', 'tail': '2o C above pre-industrial levels', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[318, 446]]}}
#   {'head': 'Paris Agreement', 'type': 'point in time', 'tail': '2020', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[318, 446]]}}
#   {'head': 'Paris Agreement', 'type': 'main subject', 'tail': 'global average temperatures well below 2o C above pre-industrial levels', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[318, 446]]}}
#   {'head': 'carbon pricing', 'type': 'facet of', 'tail': 'GHG emissions', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[424, 552]]}}
#   {'head': 'carbon prices', 'type': 'facet of', 'tail': 'GHG emissions', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[424, 552]]}}
#   {'head': 'carbon pricing policies', 'type': 'facet of', 'tail': 'GHG emissions', 'sentiment': 'Environmental Positive', 'meta': {'spans': [[424, 552]]}}
#   {'head': 'offsets', 'type': 'subclass of', 'tail': 'low-carbon technologies', 'sentiment': 'Governance Positive', 'meta': {'spans': [[530, 658]]}}
#   {'head': 'renewables', 'type': 'subclass of', 'tail': 'low-carbon technologies', 'sentiment': 'Governance Positive', 'meta': {'spans': [[530, 658]]}}
#   {'head': 'offsets', 'type': 'facet of', 'tail': 'low-carbon technologies', 'sentiment': 'Governance Positive', 'meta': {'spans': [[530, 658]]}}

# %%
save_network_html(kb_response, filename='chevron_response.html')
IPython.display.HTML(filename=filename)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# chevron_response.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 700px;
#                  height: 700px;
#                  background-color: #eeeeee;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#              #loadingBar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width: 700px;
#                  height: 700px;
#                  background-color:rgba(200,200,200,0.8);
#                  -webkit-transition: all 0.5s ease;
#                  -moz-transition: all 0.5s ease;
#                  -ms-transition: all 0.5s ease;
#                  -o-transition: all 0.5s ease;
#                  transition: all 0.5s ease;
#                  opacity:1;
#              }
#
#              #bar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width:20px;
#                  height:20px;
#                  margin:auto auto auto auto;
#                  border-radius:11px;
#                  border:2px solid rgba(30,30,30,0.05);
#                  background: rgb(0, 173, 246); /* Old browsers */
#                  box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#              }
#
#              #border {
#                  position:absolute;
#                  top:10px;
#                  left:10px;
#                  width:500px;
#                  height:23px;
#                  margin:auto auto auto auto;
#                  box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#                  border-radius:10px;
#              }
#
#              #text {
#                  position:absolute;
#                  top:8px;
#                  left:530px;
#                  width:30px;
#                  height:50px;
#                  margin:auto auto auto auto;
#                  font-size:22px;
#                  color: #000000;
#              }
#
#              div.outerBorder {
#                  position:relative;
#                  top:400px;
#                  width:600px;
#                  height:44px;
#                  margin:auto auto auto auto;
#                  border:8px solid rgba(0,0,0,0.1);
#                  background: rgb(252,252,252); /* Old browsers */
#                  background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#                  background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#                  background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#                  background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#                  background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#                  background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#                  filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#                  border-radius:72px;
#                  box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#              }
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#             <div id="loadingBar">
#               <div class="outerBorder">
#                 <div id="text">0%</div>
#                 <div id="border">
#                   <div id="bar"></div>
#                 </div>
#               </div>
#             </div>
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#A699B0", "id": "Equinor", "label": "Equinor", "shape": "circle"}, {"color": "#A699B0", "id": "Norway", "label": "Norway", "shape": "circle"}, {"color": "#A699B0", "id": "Repsol", "label": "Repsol", "shape": "circle"}, {"color": "#A699B0", "id": "Spain", "label": "Spain", "shape": "circle"}, {"color": "#A699B0", "id": "Norway\u0027s", "label": "Norway\u0027s", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage", "label": "carbon capture and storage", "shape": "circle"}, {"color": "#A699B0", "id": "carbon", "label": "carbon", "shape": "circle"}, {"color": "#A699B0", "id": "oil", "label": "oil", "shape": "circle"}, {"color": "#A699B0", "id": "energy", "label": "energy", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage technology", "label": "carbon capture and storage technology", "shape": "circle"}, {"color": "#A699B0", "id": "ConocoP", "label": "ConocoP", "shape": "circle"}, {"color": "#A699B0", "id": "Chevron", "label": "Chevron", "shape": "circle"}, {"color": "#A699B0", "id": "methane", "label": "methane", "shape": "circle"}, {"color": "#A699B0", "id": "Exxon", "label": "Exxon", "shape": "circle"}, {"color": "#A699B0", "id": "GHG", "label": "GHG", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity", "label": "carbon intensity", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity vs 2016", "label": "carbon intensity vs 2016", "shape": "circle"}, {"color": "#A699B0", "id": "2016", "label": "2016", "shape": "circle"}, {"color": "#A699B0", "id": "Shell", "label": "Shell", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage capacity", "label": "carbon capture and storage capacity", "shape": "circle"}, {"color": "#A699B0", "id": "oil equivalent", "label": "oil equivalent", "shape": "circle"}, {"color": "#A699B0", "id": "barrels

# %% [markdown]
# # Extract KB from web article

# %%
def get_sentiment(text):
    sentence_class = {}
    for id, sent in enumerate(text.split('. ')):
      if len(sent) > 512:
        sent = sent[:512]
      sentence_class[id] = classifier(sent)
    return sentence_class

# %%
def from_text_to_kb(text, article_url, span_length=128, article_title=None,
                    article_publish_date=None, verbose=False):
    # tokenize whole text
    inputs = tokenizer([text], return_tensors="pt")

    # compute span boundaries
    num_tokens = len(inputs["input_ids"][0])
    if verbose:
        print(f"Input has {num_tokens} tokens")
    num_spans = math.ceil(num_tokens / span_length)
    if verbose:
        print(f"Input has {num_spans} spans")
    overlap = math.ceil((num_spans * span_length - num_tokens) / 
                        max(num_spans - 1, 1))
    spans_boundaries = []
    start = 0
    for i in range(num_spans):
        spans_boundaries.append([start + span_length * i,
                                 start + span_length * (i + 1)])
        start -= overlap
    if verbose:
        print(f"Span boundaries are {spans_boundaries}")

    # transform input with spans
    tensor_ids = [inputs["input_ids"][0][boundary[0]:boundary[1]]
                  for boundary in spans_boundaries]
    tensor_masks = [inputs["attention_mask"][0][boundary[0]:boundary[1]]
                    for boundary in spans_boundaries]
    inputs = {
        "input_ids": torch.stack(tensor_ids),
        "attention_mask": torch.stack(tensor_masks)
    }
    id_sentence = {id:sent for id, sent in enumerate(text.split('. '))}
    # sentence_entities, entity_ner = get_ner(text)
    sentence_class = get_sentiment(text)
    # generate relations
    num_return_sequences = 3
    gen_kwargs = {
        "max_length": 256,
        "length_penalty": 0,
        "num_beams": 3,
        "num_return_sequences": num_return_sequences
    }
    generated_tokens = model.generate(
        **inputs,
        **gen_kwargs,
    )

    # decode relations
    decoded_preds = tokenizer.batch_decode(generated_tokens,
                                           skip_special_tokens=False)

    # create kb
    kb = KB()
    i = 0
    for sentence_pred in decoded_preds:
        current_span_index = i // num_return_sequences
        relations = extract_relations_from_model_output(sentence_pred)
        for relation in relations:
            for id, sent in id_sentence.items():
              if relation['head'] in sent and relation['tail'] in sent:
                relation['sentiment'] = sentence_class[id][0]['label']
            relation["meta"] = {
                article_url: {
                    "spans": [spans_boundaries[current_span_index]]
                }
            }
            kb.add_relation(relation, article_title, article_publish_date)
        i += 1

    return kb

# %%
class KB():
    def __init__(self):
        self.entities = {} # { entity_title: {...} }
        self.relations = [] # [ head: entity_title, type: ..., tail: entity_title,
          # meta: { article_url: { spans: [...] } } ]
        self.sources = {} # { article_url: {...} }

    def merge_with_kb(self, kb2):
        for r in kb2.relations:
            article_url = list(r["meta"].keys())[0]
            source_data = kb2.sources[article_url]
            self.add_relation(r, source_data["article_title"],
                              source_data["article_publish_date"])

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r2):
        r1 = [r for r in self.relations
              if self.are_relations_equal(r2, r)][0]

        # if different article
        article_url = list(r2["meta"].keys())[0]
        if article_url not in r1["meta"]:
            r1["meta"][article_url] = r2["meta"][article_url]

        # if existing article
        else:
            spans_to_add = [span for span in r2["meta"][article_url]["spans"]
                            if span not in r1["meta"][article_url]["spans"]]
            r1["meta"][article_url]["spans"] += spans_to_add

    def get_wikipedia_data(self, candidate_entity):
        try:
            page = wikipedia.page(candidate_entity, auto_suggest=False)
            entity_data = {
                "title": page.title,
                "url": page.url,
                "summary": page.summary
            }
            return entity_data
        except:
            return None

    def add_entity(self, e):
        self.entities[e] = {'url': ''}

    def add_relation(self, r, article_title, article_publish_date):
        # manage new entities
        entities = [r["head"], r["tail"]]

        for e in entities:
            self.add_entity(e)

        # rename relation entities with their wikipedia titles
        # r["head"] = entities[0]["title"]
        # r["tail"] = entities[1]["title"]
        # add source if not in kb
        article_url = list(r["meta"].keys())[0]
        if article_url not in self.sources:
            self.sources[article_url] = {
                "article_title": article_title,
                "article_publish_date": article_publish_date
            }
        
        # manage new relation
        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self):
        print("Entities:")
        for e in self.entities.items():
            print(f"  {e}")
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")
        print("Sources:")
        for s in self.sources.items():
            print(f"  {s}")

# %%
def get_article(url):
    article = Article(url)
    article.download()
    article.parse()
    return article

def from_url_to_kb(url):
    article = get_article(url)
    config = {
        "article_title": article.title,
        "article_publish_date": article.publish_date
    }
    kb = from_text_to_kb(article.text, article.url, **config)
    return kb

# %% [markdown]
# # Google News: extract KB from multiple articles

# %%
def get_news_links(query, lang="en", region="US", pages=1, max_links=100000):
    googlenews = GoogleNews(lang=lang, region=region)
    googlenews.search(query)
    all_urls = []
    for page in range(pages):
        googlenews.get_page(page)
        all_urls += googlenews.get_links()
    return list(set(all_urls))[:max_links]

def from_urls_to_kb(urls, verbose=False):
    kb = KB()
    if verbose:
        print(f"{len(urls)} links to visit")
    for url in urls:
        if verbose:
            print(f"Visiting {url}...")
        try:
            kb_url = from_url_to_kb(url)
            kb.merge_with_kb(kb_url)
        except ArticleException:
            if verbose:
                print(f"  Couldn't download article at url {url}")
    return kb

# %%
import pickle

def save_kb(kb, filename):
    with open(filename, "wb") as f:
        pickle.dump(kb, f)

def load_kb(filename):
    res = None
    with open(filename, "rb") as f:
        res = pickle.load(f)
    return res

# %% [markdown]
# # Visualize KB

# %%
def save_network_html(kb, filename="network.html"):

    color_map = {
        'Governance Negative': '#070245',
        'Governance Neutral': '#4D6CB9',
        'Governance Positive': '#72EFF5',
        'Environmental Negative': '#214124',
        'Environmental Neutral':  '#29A734',
        'Environmental Positive': '#28EA1C',
        'Social Negative': '#CEB501',
        'Social Neutral': '#E6CA00',
        'Social Positive': '#FAFA03'
    }
    # create network
    net = Network(directed=True, width="700px", height="700px", bgcolor="#eeeeee", notebook=True)

    # nodes
    color_entity = "#A699B0"
    for e in kb.entities:
        net.add_node(e, shape="circle", color=color_entity)

    # edges
    for r in kb.relations:
        # print(r)
        if r['head'] not in kb.entities or r['tail'] not in kb.entities:
          continue
        if 'sentiment' in r:
          net.add_edge(r["head"], r["tail"],
                      title=r["type"] + f'({r["sentiment"]})', label=r["type"], color=color_map[r['sentiment']])
        else:
          net.add_edge(r["head"], r["tail"],
                      title=r["type"], label=r["type"], color=color_entity)
        
    # save network
    net.repulsion(
        node_distance=200,
        central_gravity=0.2,
        spring_length=200,
        spring_strength=0.05,
        damping=0.09
    )
    net.set_edge_smooth('dynamic')
    # print(net)
    net.show(filename)

# %%
urls = """https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4
https://carbontracker.org/reports/fault-lines/	
https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/
https://www.unpri.org/sustainability-issues/accounting-for-climate-change
https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d
https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en
https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050	
https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/"""
urls = urls.split('\n')

# %%
# news_links = get_news_links("Google", pages=5, max_links=20)
# kb = from_urls_to_kb(news_links, verbose=True)
# filename = "network_3_google.html"
# save_network_html(kb, filename=filename)
# save_kb(kb, filename.split(".")[0] + ".p")
# IPython.display.HTML(filename=filename)

# %%
kb = from_urls_to_kb(urls, verbose=True)
kb.print()
# Out:
# 8 links to visit
# Visiting https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4...
# Visiting https://carbontracker.org/reports/fault-lines/	...
# Visiting https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/...
# Visiting https://www.unpri.org/sustainability-issues/accounting-for-climate-change...
# Visiting https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d...
# Visiting https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en...
# Visiting https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050	...
# Visiting https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/...
# Entities:
#   ('Equinor', {'url': ''})
#   ('Norway', {'url': ''})
#   ('Repsol', {'url': ''})
#   ('Spain', {'url': ''})
#   ("Norway's", {'url': ''})
#   ('carbon capture and storage', {'url': ''})
#   ('carbon', {'url': ''})
#   ('oil', {'url': ''})
#   ('energy', {'url': ''})
#   ('carbon capture and storage technology', {'url': ''})
#   ('ConocoP', {'url': ''})
#   ('Chevron', {'url': ''})
#   ('methane', {'url': ''})
#   ('Exxon', {'url': ''})
#   ('GHG', {'url': ''})
#   ('carbon intensity', {'url': ''})
#   ('carbon intensity vs 2016', {'url': ''})
#   ('2016', {'url': ''})
#   ('Shell', {'url': ''})
#   ('carbon capture and storage capacity', {'url': ''})
#   ('oil equivalent', {'url': ''})
#   ('barrels', {'url': ''})
#   ('barrels of oil', {'url': ''})
#   ('diesel generator', {'url': ''})
#   ('offshore platform', {'url': ''})
#   ('fossil fuel', {'url': ''})
#   ('CO 2', {'url': ''})
#   ('lower carbon economy', {'url': ''})
#   ('shift to a lower carbon economy', {'url': ''})
#   ('Breaking the Habit', {'url': ''})
#   ('Carbon Tracker', {'url': ''})
#   ('Carbon Tracker’s', {'url': ''})
#   ('International Accounting Standards Board', {'url': ''})
#   ('London', {'url': ''})
#   ('Open Letter on Accounting Standards', {'url': ''})
#   ('COP 26', {'url': ''})
#   ('Mark Carney', {'url': ''})
#   ('Finance Adviser', {'url': ''})
#   ('extreme weather events', {'url': ''})
#   ('climate change', {'url': ''})
#   ('extreme weather', {'url': ''})
#   ('BP', {'url': ''})
#   ('Paris Agreement', {'url': ''})
#   ('fossil fuels', {'url': ''})
#   ('climate', {'url': ''})
#   ('climate-related risks', {'url': ''})
#   ('PRI', {'url': ''})
#   ('Fiona Reynolds', {'url': ''})
#   ('profits', {'url': ''})
#   ('assets', {'url': ''})
#   ('International Financial Reporting Standards', {'url': ''})
#   ('financial statements', {'url': ''})
#   ('financial statement', {'url': ''})
#   ('Allianz SE', {'url': ''})
#   ('Net-Zero Asset Owner Alliance', {'url': ''})
#   ('UN-Convened Net-Zero Asset Owner Alliance', {'url': ''})
#   ('CalPERS', {'url': ''})
#   ('PERS', {'url': ''})
#   ('Stephanie Pfeifer', {'url': ''})
#   ('Institutional Investors Group on Climate Change', {'url': ''})
#   ('IASB', {'url': ''})
#   ('Emma Herd', {'url': ''})
#   ('Chief Executive Officer', {'url': ''})
#   ('Australia/New Zealand', {'url': ''})
#   ('climate risk', {'url': ''})
#   ('European membership body', {'url': ''})
#   ('membership body', {'url': ''})
#   ('IFRS', {'url': ''})
#   ('annual report', {'url': ''})
#   ('2020', {'url': ''})
#   ('oil companies', {'url': ''})
#   ('ICAEW', {'url': ''})
#   ('professional body', {'url': ''})
#   ('ISAs', {'url': ''})
#   ('IAASB', {'url': ''})
#   ('ISA', {'url': ''})
#   ('auditors', {'url': ''})
#   ('accounting', {'url': ''})
#   ('accounting bodies', {'url': ''})
#   ('World Heritage Site', {'url': ''})
#   ('UNESCO', {'url': ''})
#   ('John F. Kennedy School of Government', {'url': ''})
#   ('Harvard University', {'url': ''})
#   ('World War II', {'url': ''})
#   ('Holocaust', {'url': ''})
#   ('2006', {'url': ''})
#   ('SDS', {'url': ''})
#   ('Covid-19 pandemic', {'url': ''})
#   ('2019', {'url': ''})
#   ('1970s', {'url': ''})
#   ('1970', {'url': ''})
#   ('Coal demand', {'url': ''})
#   ('energy demand', {'url': ''})
#   ('2015 Paris Agreement', {'url': ''})
#   ('2015', {'url': ''})
#   ('global warming', {'url': ''})
#   ('net zero emissions by 2050', {'url': ''})
#   ('2050', {'url': ''})
#   ('net zero emissions', {'url': ''})
#   ('2030 emissions unconditionally', {'url': ''})
#   ('2030', {'url': ''})
#   ('Argentina', {'url': ''})
#   ('UN', {'url': ''})
#   ('People’s Party', {'url': ''})
#   ('right wing', {'url': ''})
#   ('coalition government', {'url': ''})
#   ('January 2020', {'url': ''})
#   ('Brazil', {'url': ''})
#   ('deforestation reached a 12-year high', {'url': ''})
#   ('deforestation', {'url': ''})
#   ('Justin Trudeau', {'url': ''})
#   ('prime minister', {'url': ''})
#   ('narrowly scraped a second term as prime minister', {'url': ''})
#   ('President', {'url': ''})
#   ('Sebastian Piñera', {'url': ''})
#   ('civil unrest', {'url': ''})
#   ('Santiago', {'url': ''})
#   ('Chile', {'url': ''})
#   ('Xi Jinping', {'url': ''})
#   ('coronavirus pandemic', {'url': ''})
#   ('Beijing', {'url': ''})
#   ('Carlos Alvarado Quesada', {'url': ''})
#   ('president', {'url': ''})
#   ('Colombia', {'url': ''})
#   ('Costa Rica', {'url': ''})
#   ('hydropower', {'url': ''})
#   ('renewable', {'url': ''})
#   ('renewables', {'url': ''})
#   ('electricity', {'url': ''})
#   ('June 2019 parliamentary elections', {'url': ''})
#   ('“red bloc” parties', {'url': ''})
#   ('Cop23', {'url': ''})
#   ('2017', {'url': ''})
#   ('UN climate summit', {'url': ''})
#   ('net zero target', {'url': ''})
#   ('27 June 2019', {'url': ''})
#   ('negotiations to form a government', {'url': ''})
#   ('June 2019', {'url': ''})
#   ('High Council for the Climate', {'url': ''})
#   ('France', {'url': ''})
#   ('landmark court ruling', {'url': ''})
#   ('phase out coal by 2030', {'url': ''})
#   ('Germany', {'url': ''})
#   ('phase out coal', {'url': ''})
#   ('last coal power plant', {'url': ''})
#   ('Iceland', {'url': ''})
#   ('nuclear capacity', {'url': ''})
#   ('coal power plant', {'url': ''})
#   ('Ireland', {'url': ''})
#   ('greenhouse gas emissions', {'url': ''})
#   ('Japan', {'url': ''})
#   ('island state', {'url': ''})
#   ('fifth-largest emitter', {'url': ''})
#   ('coal power', {'url': ''})
#   ('coal', {'url': ''})
#   ('Laos', {'url': ''})
#   ('southeast Asia', {'url': ''})
#   ('southeast Asian', {'url': ''})
#   ('storm surge', {'url': ''})
#   ('coastal erosion', {'url': ''})
#   ('Nepal', {'url': ''})
#   ('Himalayan glaciers', {'url': ''})
#   ('Himalaya', {'url': ''})
#   ('greenhouse gases', {'url': ''})
#   ('greenhouse gas', {'url': ''})
#   ('biogenic methane', {'url': ''})
#   ('national forests', {'url': ''})
#   ('Panama', {'url': ''})
#   ('the UN', {'url': ''})
#   ('Portugal', {'url': ''})
#   ('EU', {'url': ''})
#   ('member states', {'url': ''})
#   ('Slovakia', {'url': ''})
#   ('South Korean president', {'url': ''})
#   ('Moon Jae-in', {'url': ''})
#   ('South Korea', {'url': ''})
#   ('landslide victory', {'url': ''})
#   ('April 2020', {'url': ''})
#   ('landslide victory in April 2020', {'url': ''})
#   ('Democratic Party', {'url': ''})
#   ('legislated its net zero target in 2017', {'url': ''})
#   ('legislated its net zero target', {'url': ''})
#   ('withdraw the US from the pact', {'url': ''})
#   ('Donald Trump', {'url': ''})
#   ('Donald Trump’s', {'url': ''})
#   ('climate strategy', {'url': ''})
#   ('Turkish Republic', {'url': ''})
#   ('land-locked country', {'url': ''})
#   ('Sustainable Development Goals', {'url': ''})
#   ('United Nations', {'url': ''})
#   ('coal phase-out', {'url': ''})
#   ('coal phase-out date', {'url': ''})
#   ('Scotland', {'url': ''})
#   ('devolved parliament', {'url': ''})
#   ('Scotland’s', {'url': ''})
#   ('parliament', {'url': ''})
#   ('North Sea oilfields', {'url': ''})
#   ('United States of America', {'url': ''})
#   ('North Sea', {'url': ''})
#   ('US', {'url': ''})
#   ('elected president of the US', {'url': ''})
#   ('Joe Biden', {'url': ''})
#   ('elected president of the US in November 2020', {'url': ''})
# Relations:
#   {'head': 'Equinor', 'type': 'country', 'tail': 'Norway', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[0, 128]]}}}
#   {'head': 'Repsol', 'type': 'country', 'tail': 'Spain', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[0, 128]]}}}
#   {'head': 'Equinor', 'type': 'country', 'tail': "Norway's", 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[0, 128]]}}}
#   {'head': 'carbon capture and storage', 'type': 'uses', 'tail': 'carbon', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[121, 249]]}}}
#   {'head': 'oil', 'type': 'subclass of', 'tail': 'energy', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[121, 249]]}}}
#   {'head': 'carbon capture and storage technology', 'type': 'uses', 'tail': 'carbon', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[121, 249]]}}}
#   {'head': 'ConocoP', 'type': 'subsidiary', 'tail': 'ConocoP', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[242, 370]]}}}
#   {'head': 'ConocoP', 'type': 'owned by', 'tail': 'ConocoP', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[242, 370]]}}}
#   {'head': 'Chevron', 'type': 'owner of', 'tail': 'ConocoP', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[242, 370]]}}}
#   {'head': 'ConocoP', 'type': 'owned by', 'tail': 'Chevron', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[242, 370]]}}}
#   {'head': 'Equinor', 'type': 'product or material produced', 'tail': 'methane', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[363, 491]]}}}
#   {'head': 'Exxon', 'type': 'product or material produced', 'tail': 'methane', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[363, 491]]}}}
#   {'head': 'methane', 'type': 'instance of', 'tail': 'GHG', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[363, 491]]}}}
#   {'head': 'carbon intensity', 'type': 'facet of', 'tail': 'carbon', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[484, 612]]}}}
#   {'head': 'carbon intensity vs 2016', 'type': 'point in time', 'tail': '2016', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[484, 612]]}}}
#   {'head': 'Shell', 'type': 'product or material produced', 'tail': 'carbon capture and storage', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[605, 733]]}}}
#   {'head': 'Shell', 'type': 'industry', 'tail': 'carbon capture and storage', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[605, 733]]}}}
#   {'head': 'Shell', 'type': 'product or material produced', 'tail': 'carbon capture and storage capacity', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[605, 733]]}}}
#   {'head': 'oil equivalent', 'type': 'subclass of', 'tail': 'barrels', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[726, 854]]}}}
#   {'head': 'oil equivalent', 'type': 'subclass of', 'tail': 'barrels of oil', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[726, 854]]}}}
#   {'head': 'diesel generator', 'type': 'part of', 'tail': 'offshore platform', 'sentiment': 'Environmental Positive', 'meta': {'https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4': {'spans': [[726, 854]]}}}
#   {'head': 'fossil fuel', 'type': 'has part', 'tail': 'CO 2', 'sentiment': 'Environmental Negative', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[0, 128]]}}}
#   {'head': 'lower carbon economy', 'type': 'facet of', 'tail': 'shift to a lower carbon economy', 'sentiment': 'Environmental Negative', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[0, 128]]}}}
#   {'head': 'fossil fuel', 'type': 'has parts of the class', 'tail': 'CO 2', 'sentiment': 'Environmental Negative', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[0, 128]]}}}
#   {'head': 'Breaking the Habit', 'type': 'publisher', 'tail': 'Carbon Tracker', 'sentiment': 'Environmental Positive', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[94, 222]]}}}
#   {'head': 'Breaking the Habit', 'type': 'publisher', 'tail': 'Carbon Tracker’s', 'sentiment': 'Environmental Positive', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[94, 222]]}}}
#   {'head': 'Breaking the Habit', 'type': 'author', 'tail': 'Carbon Tracker', 'sentiment': 'Environmental Positive', 'meta': {'https://carbontracker.org/reports/fault-lines/': {'spans': [[94, 222]]}}}
#   {'head': 'International Accounting Standards Board', 'type': 'headquarters location', 'tail': 'London', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[0, 128]]}}}
#   {'head': 'Open Letter on Accounting Standards', 'type': 'author', 'tail': 'International Accounting Standards Board', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[0, 128]]}}}
#   {'head': 'COP 26', 'type': 'participant', 'tail': 'Mark Carney', 'sentiment': 'Environmental Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[122, 250]]}}}
#   {'head': 'Mark Carney', 'type': 'participant in', 'tail': 'COP 26', 'sentiment': 'Environmental Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[122, 250]]}}}
#   {'head': 'Mark Carney', 'type': 'position held', 'tail': 'Finance Adviser', 'sentiment': 'Environmental Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[122, 250]]}}}
#   {'head': 'extreme weather events', 'type': 'has cause', 'tail': 'climate change', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[244, 372]]}}}
#   {'head': 'extreme weather events', 'type': 'facet of', 'tail': 'climate change', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[244, 372]]}}}
#   {'head': 'extreme weather', 'type': 'has cause', 'tail': 'climate change', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[244, 372]]}}}
#   {'head': 'BP', 'type': 'product or material produced', 'tail': 'fossil fuel', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[366, 494]]}}}
#   {'head': 'Paris Agreement', 'type': 'main subject', 'tail': 'climate change', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[366, 494]]}}}
#   {'head': 'BP', 'type': 'product or material produced', 'tail': 'fossil fuels', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[366, 494]]}}}
#   {'head': 'climate', 'type': 'facet of', 'tail': 'climate change', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[488, 616]]}}}
#   {'head': 'climate-related risks', 'type': 'facet of', 'tail': 'climate change', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[488, 616]]}}}
#   {'head': 'climate-related risks', 'type': 'facet of', 'tail': 'climate', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[488, 616]]}}}
#   {'head': 'PRI', 'type': 'chairperson', 'tail': 'Fiona Reynolds', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[610, 738]]}}}
#   {'head': 'profits', 'type': 'subclass of', 'tail': 'assets', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[610, 738]]}}}
#   {'head': 'profits', 'type': 'has part', 'tail': 'assets', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[610, 738]]}}}
#   {'head': 'International Financial Reporting Standards', 'type': 'facet of', 'tail': 'financial statements', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[732, 860]]}}}
#   {'head': 'International Financial Reporting Standards', 'type': 'facet of', 'tail': 'financial statement', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[732, 860]]}}}
#   {'head': 'International Financial Reporting Standards', 'type': 'use', 'tail': 'financial statements', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[732, 860]]}}}
#   {'head': 'Allianz SE', 'type': 'member of', 'tail': 'Net-Zero Asset Owner Alliance', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[854, 982]]}}}
#   {'head': 'Allianz SE', 'type': 'member of', 'tail': 'UN-Convened Net-Zero Asset Owner Alliance', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[854, 982]]}}}
#   {'head': 'Net-Zero Asset Owner Alliance', 'type': 'has part', 'tail': 'Allianz SE', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[854, 982]]}}}
#   {'head': 'CalPERS', 'type': 'instance of', 'tail': 'PERS', 'sentiment': 'Governance Neutral', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[976, 1104]]}}}
#   {'head': 'PERS', 'type': 'subsidiary', 'tail': 'CalPERS', 'sentiment': 'Governance Neutral', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[976, 1104]]}}}
#   {'head': 'CalPERS', 'type': 'parent organization', 'tail': 'PERS', 'sentiment': 'Governance Neutral', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[976, 1104]]}}}
#   {'head': 'PERS', 'type': 'has part', 'tail': 'CalPERS', 'sentiment': 'Governance Neutral', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[976, 1104]]}}}
#   {'head': 'CalPERS', 'type': 'part of', 'tail': 'PERS', 'sentiment': 'Governance Neutral', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[976, 1104]]}}}
#   {'head': 'Stephanie Pfeifer', 'type': 'employer', 'tail': 'Institutional Investors Group on Climate Change', 'sentiment': 'Environmental Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1098, 1226]]}}}
#   {'head': 'Stephanie Pfeifer', 'type': 'member of', 'tail': 'IASB', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1098, 1226]]}}}
#   {'head': 'Institutional Investors Group on Climate Change', 'type': 'founded by', 'tail': 'Stephanie Pfeifer', 'sentiment': 'Environmental Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1098, 1226]]}}}
#   {'head': 'Emma Herd', 'type': 'occupation', 'tail': 'Chief Executive Officer', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1220, 1348]]}}}
#   {'head': 'Emma Herd', 'type': 'position held', 'tail': 'Chief Executive Officer', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1220, 1348]]}}}
#   {'head': 'Emma Herd', 'type': 'country of citizenship', 'tail': 'Australia/New Zealand', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1220, 1348]]}}}
#   {'head': 'International Accounting Standards Board', 'type': 'main subject', 'tail': 'climate risk', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1342, 1470]]}}}
#   {'head': 'International Accounting Standards Board', 'type': 'field of work', 'tail': 'climate risk', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1342, 1470]]}}}
#   {'head': 'International Accounting Standards Board', 'type': 'main subject', 'tail': 'climate change', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1342, 1470]]}}}
#   {'head': 'Institutional Investors Group on Climate Change', 'type': 'instance of', 'tail': 'European membership body', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1464, 1592]]}}}
#   {'head': 'Institutional Investors Group on Climate Change', 'type': 'instance of', 'tail': 'membership body', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1464, 1592]]}}}
#   {'head': 'Institutional Investors Group on Climate Change', 'type': 'field of work', 'tail': 'climate change', 'sentiment': 'Governance Positive', 'meta': {'https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/': {'spans': [[1464, 1592]]}}}
#   {'head': 'IFRS', 'type': 'publisher', 'tail': 'IASB', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[0, 128]]}}}
#   {'head': 'IASB', 'type': 'owner of', 'tail': 'IFRS', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[0, 128]]}}}
#   {'head': 'IFRS', 'type': 'owned by', 'tail': 'IASB', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[0, 128]]}}}
#   {'head': 'financial statement', 'type': 'different from', 'tail': 'annual report', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[0, 128]]}}}
#   {'head': 'annual report', 'type': 'different from', 'tail': 'financial statement', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[0, 128]]}}}
#   {'head': 'IFRS', 'type': 'instance of', 'tail': 'International Financial Reporting Standards', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[108, 236]]}}}
#   {'head': 'International Financial Reporting Standards', 'type': 'part of', 'tail': 'IFRS', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[108, 236]]}}}
#   {'head': 'IFRS', 'type': 'part of', 'tail': 'International Financial Reporting Standards', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[108, 236]]}}}
#   {'head': 'Paris Agreement', 'type': 'point in time', 'tail': '2020', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[216, 344]]}}}
#   {'head': 'International Financial Reporting Standards', 'type': 'publisher', 'tail': 'IASB', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[216, 344]]}}}
#   {'head': 'BP', 'type': 'industry', 'tail': 'oil companies', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[324, 452]]}}}
#   {'head': 'BP', 'type': 'product or material produced', 'tail': 'oil', 'sentiment': 'Environmental Negative', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[324, 452]]}}}
#   {'head': 'ICAEW', 'type': 'instance of', 'tail': 'professional body', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[324, 452]]}}}
#   {'head': 'ISAs', 'type': 'publisher', 'tail': 'IAASB', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[432, 560]]}}}
#   {'head': 'ISA', 'type': 'publisher', 'tail': 'IAASB', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[432, 560]]}}}
#   {'head': 'IAASB', 'type': 'product or material produced', 'tail': 'ISAs', 'sentiment': 'Environmental Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[432, 560]]}}}
#   {'head': 'auditors', 'type': 'field of this occupation', 'tail': 'accounting', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[540, 668]]}}}
#   {'head': 'accounting', 'type': 'practiced by', 'tail': 'auditors', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[540, 668]]}}}
#   {'head': 'IASB', 'type': 'field of work', 'tail': 'auditors', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[540, 668]]}}}
#   {'head': 'auditors', 'type': 'part of', 'tail': 'accounting bodies', 'sentiment': 'Governance Positive', 'meta': {'https://www.unpri.org/sustainability-issues/accounting-for-climate-change': {'spans': [[540, 668]]}}}
#   {'head': 'World Heritage Site', 'type': 'maintained by', 'tail': 'UNESCO', 'meta': {'https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d': {'spans': [[0, 128]]}, 'https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en': {'spans': [[0, 128]]}}}
#   {'head': 'John F. Kennedy School of Government', 'type': 'part of', 'tail': 'Harvard University', 'meta': {'https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d': {'spans': [[0, 128]]}, 'https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en': {'spans': [[0, 128]]}}}
#   {'head': 'World War II', 'type': 'has effect', 'tail': 'Holocaust', 'meta': {'https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d': {'spans': [[0, 128]]}, 'https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en': {'spans': [[0, 128]]}}}
#   {'head': '2006', 'type': 'point in time', 'tail': '2006', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050': {'spans': [[0, 128], [21, 149]]}}}
#   {'head': 'SDS', 'type': 'point in time', 'tail': '2006', 'meta': {'https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050': {'spans': [[0, 128]]}}}
#   {'head': 'Covid-19 pandemic', 'type': 'point in time', 'tail': '2019', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050': {'spans': [[0, 128]]}}}
#   {'head': '1970s', 'type': 'point in time', 'tail': '1970', 'sentiment': 'Environmental Negative', 'meta': {'https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050': {'spans': [[21, 149]]}}}
#   {'head': 'Coal demand', 'type': 'subclass of', 'tail': 'energy demand', 'meta': {'https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050': {'spans': [[21, 149]]}}}
#   {'head': '2015 Paris Agreement', 'type': 'point in time', 'tail': '2015', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[0, 128]]}}}
#   {'head': '2015 Paris Agreement', 'type': 'main subject', 'tail': 'global warming', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[0, 128]]}}}
#   {'head': '2015 Paris Agreement', 'type': 'facet of', 'tail': 'global warming', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[0, 128]]}}}
#   {'head': 'net zero emissions by 2050', 'type': 'point in time', 'tail': '2050', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[124, 252]]}}}
#   {'head': '2050', 'type': 'point in time', 'tail': '2050', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[124, 252], [248, 376]]}}}
#   {'head': 'net zero emissions', 'type': 'point in time', 'tail': '2050', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[124, 252]]}}}
#   {'head': '2030 emissions unconditionally', 'type': 'point in time', 'tail': '2030', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[248, 376]]}}}
#   {'head': 'Argentina', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[248, 376]]}}}
#   {'head': 'People’s Party', 'type': 'political ideology', 'tail': 'right wing', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[372, 500]]}}}
#   {'head': 'coalition government', 'type': 'inception', 'tail': 'January 2020', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[372, 500]]}}}
#   {'head': 'People’s Party', 'type': 'country', 'tail': 'Brazil', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[372, 500]]}}}
#   {'head': 'deforestation reached a 12-year high', 'type': 'point in time', 'tail': '2030', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[496, 624]]}}}
#   {'head': 'deforestation', 'type': 'has cause', 'tail': 'carbon', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[496, 624]]}}}
#   {'head': 'Justin Trudeau', 'type': 'position held', 'tail': 'prime minister', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[620, 748]]}}}
#   {'head': 'prime minister', 'type': 'officeholder', 'tail': 'Justin Trudeau', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[620, 748]]}}}
#   {'head': 'Justin Trudeau', 'type': 'candidacy in election', 'tail': 'narrowly scraped a second term as prime minister', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[620, 748]]}}}
#   {'head': 'narrowly scraped a second term as prime minister', 'type': 'candidate', 'tail': 'Justin Trudeau', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[620, 748]]}}}
#   {'head': 'President', 'type': 'officeholder', 'tail': 'Sebastian Piñera', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[744, 872]]}}}
#   {'head': 'Sebastian Piñera', 'type': 'position held', 'tail': 'President', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[744, 872]]}}}
#   {'head': 'civil unrest', 'type': 'location', 'tail': 'Santiago', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[744, 872]]}}}
#   {'head': 'Chile', 'type': 'head of state', 'tail': 'Sebastian Piñera', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[744, 872]]}}}
#   {'head': 'President', 'type': 'officeholder', 'tail': 'Xi Jinping', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[868, 996]]}}}
#   {'head': 'Xi Jinping', 'type': 'position held', 'tail': 'President', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[868, 996]]}}}
#   {'head': 'coronavirus pandemic', 'type': 'location', 'tail': 'Beijing', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[868, 996]]}}}
#   {'head': 'Carlos Alvarado Quesada', 'type': 'position held', 'tail': 'president', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[992, 1120]]}}}
#   {'head': 'Colombia', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[992, 1120]]}}}
#   {'head': 'Costa Rica', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[992, 1120]]}}}
#   {'head': 'hydropower', 'type': 'subclass of', 'tail': 'renewable', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1116, 1244]]}}}
#   {'head': 'hydropower', 'type': 'subclass of', 'tail': 'renewables', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1116, 1244]]}}}
#   {'head': 'hydropower', 'type': 'subclass of', 'tail': 'electricity', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1116, 1244]]}}}
#   {'head': 'June 2019 parliamentary elections', 'type': 'successful candidate', 'tail': '“red bloc” parties', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1240, 1368]]}}}
#   {'head': '“red bloc” parties', 'type': 'participant in', 'tail': 'June 2019 parliamentary elections', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1240, 1368]]}}}
#   {'head': 'June 2019 parliamentary elections', 'type': 'candidate', 'tail': '“red bloc” parties', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1240, 1368]]}}}
#   {'head': 'Cop23', 'type': 'point in time', 'tail': '2017', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1364, 1492]]}}}
#   {'head': 'Cop23', 'type': 'instance of', 'tail': 'UN climate summit', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1364, 1492]]}}}
#   {'head': 'UN climate summit', 'type': 'point in time', 'tail': '2017', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1364, 1492]]}}}
#   {'head': 'net zero target', 'type': 'point in time', 'tail': '27 June 2019', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1488, 1616]]}}}
#   {'head': 'net zero target', 'type': 'publication date', 'tail': '27 June 2019', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1488, 1616]]}}}
#   {'head': 'negotiations to form a government', 'type': 'point in time', 'tail': 'June 2019', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1488, 1616]]}}}
#   {'head': 'High Council for the Climate', 'type': 'country', 'tail': 'France', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1612, 1740]]}}}
#   {'head': 'landmark court ruling', 'type': 'country', 'tail': 'France', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1612, 1740]]}}}
#   {'head': 'landmark court ruling', 'type': 'applies to jurisdiction', 'tail': 'France', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1612, 1740]]}}}
#   {'head': 'phase out coal by 2030', 'type': 'country', 'tail': 'Germany', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1736, 1864]]}}}
#   {'head': 'phase out coal by 2030', 'type': 'point in time', 'tail': '2030', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1736, 1864]]}}}
#   {'head': 'phase out coal', 'type': 'country', 'tail': 'Germany', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1736, 1864]]}}}
#   {'head': 'last coal power plant', 'type': 'country', 'tail': 'Iceland', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1860, 1988]]}}}
#   {'head': 'nuclear capacity', 'type': 'country', 'tail': 'Iceland', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1860, 1988]]}}}
#   {'head': 'coal power plant', 'type': 'subclass of', 'tail': 'fossil fuel', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1860, 1988]]}}}
#   {'head': 'coalition government', 'type': 'country', 'tail': 'Ireland', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1984, 2112]]}}}
#   {'head': 'Paris Agreement', 'type': 'main subject', 'tail': 'greenhouse gas emissions', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1984, 2112]]}}}
#   {'head': 'Paris Agreement', 'type': 'facet of', 'tail': 'greenhouse gas emissions', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[1984, 2112]]}}}
#   {'head': 'Japan', 'type': 'instance of', 'tail': 'island state', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2108, 2236]]}}}
#   {'head': 'fifth-largest emitter', 'type': 'country', 'tail': 'Japan', 'sentiment': 'Governance Neutral', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2108, 2236]]}}}
#   {'head': 'coal power', 'type': 'uses', 'tail': 'coal', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2108, 2236]]}}}
#   {'head': 'Laos', 'type': 'part of', 'tail': 'southeast Asia', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2232, 2360]]}}}
#   {'head': 'southeast Asia', 'type': 'has part', 'tail': 'Laos', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2232, 2360]]}}}
#   {'head': 'Laos', 'type': 'part of', 'tail': 'southeast Asian', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2232, 2360]]}}}
#   {'head': 'southeast Asian', 'type': 'has part', 'tail': 'Laos', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2232, 2360]]}}}
#   {'head': 'storm surge', 'type': 'has effect', 'tail': 'coastal erosion', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2232, 2360]]}}}
#   {'head': 'Nepal', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2356, 2484]]}}}
#   {'head': 'Paris Agreement', 'type': 'point in time', 'tail': '2050', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2356, 2484]]}}}
#   {'head': 'Himalayan glaciers', 'type': 'country', 'tail': 'Nepal', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2480, 2608]]}}}
#   {'head': 'Himalaya', 'type': 'country', 'tail': 'Nepal', 'sentiment': 'Environmental Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2480, 2608]]}}}
#   {'head': 'methane', 'type': 'subject has role', 'tail': 'greenhouse gases', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2604, 2732]]}}}
#   {'head': 'methane', 'type': 'subject has role', 'tail': 'greenhouse gas', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2604, 2732]]}}}
#   {'head': 'biogenic methane', 'type': 'subclass of', 'tail': 'greenhouse gases', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2604, 2732]]}}}
#   {'head': 'national forests', 'type': 'country', 'tail': 'Panama', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2728, 2856]]}}}
#   {'head': 'Panama', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2728, 2856]]}}}
#   {'head': 'Panama', 'type': 'member of', 'tail': 'the UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2728, 2856]]}}}
#   {'head': 'Portugal', 'type': 'member of', 'tail': 'EU', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2852, 2980]]}}}
#   {'head': 'EU', 'type': 'contains administrative territorial entity', 'tail': 'Portugal', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2852, 2980]]}}}
#   {'head': 'member states', 'type': 'part of', 'tail': 'EU', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2852, 2980]]}}}
#   {'head': 'EU', 'type': 'contains administrative territorial entity', 'tail': 'Slovakia', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2976, 3104]]}}}
#   {'head': 'Slovakia', 'type': 'member of', 'tail': 'EU', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[2976, 3104]]}}}
#   {'head': 'South Korean president', 'type': 'officeholder', 'tail': 'Moon Jae-in', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3100, 3228]]}}}
#   {'head': 'Moon Jae-in', 'type': 'position held', 'tail': 'South Korean president', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3100, 3228]]}}}
#   {'head': 'South Korea', 'type': 'head of state', 'tail': 'Moon Jae-in', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3100, 3228]]}}}
#   {'head': 'landslide victory', 'type': 'point in time', 'tail': 'April 2020', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3224, 3352]]}}}
#   {'head': 'landslide victory in April 2020', 'type': 'candidate', 'tail': 'Democratic Party', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3224, 3352]]}}}
#   {'head': 'landslide victory', 'type': 'candidate', 'tail': 'Democratic Party', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3224, 3352]]}}}
#   {'head': 'legislated its net zero target in 2017', 'type': 'point in time', 'tail': '2017', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3348, 3476]]}}}
#   {'head': 'legislated its net zero target', 'type': 'point in time', 'tail': '2017', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3348, 3476]]}}}
#   {'head': 'legislated its net zero target', 'type': 'publication date', 'tail': '2017', 'sentiment': 'Governance Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3348, 3476]]}}}
#   {'head': 'withdraw the US from the pact', 'type': 'participant', 'tail': 'Donald Trump', 'sentiment': 'Governance Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3472, 3600]]}}}
#   {'head': 'withdraw the US from the pact', 'type': 'author', 'tail': 'Donald Trump', 'sentiment': 'Governance Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3472, 3600]]}}}
#   {'head': 'withdraw the US from the pact', 'type': 'participant', 'tail': 'Donald Trump’s', 'sentiment': 'Governance Negative', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3472, 3600]]}}}
#   {'head': 'climate strategy', 'type': 'country', 'tail': 'Turkish Republic', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3596, 3724]]}}}
#   {'head': 'Turkish Republic', 'type': 'instance of', 'tail': 'land-locked country', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3596, 3724]]}}}
#   {'head': 'Sustainable Development Goals', 'type': 'creator', 'tail': 'United Nations', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3596, 3724]]}}}
#   {'head': 'coal', 'type': 'subclass of', 'tail': 'energy', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3720, 3848]]}}}
#   {'head': 'coal phase-out', 'type': 'facet of', 'tail': 'coal', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3720, 3848]]}}}
#   {'head': 'coal phase-out date', 'type': 'facet of', 'tail': 'coal', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3720, 3848]]}}}
#   {'head': 'Scotland', 'type': 'legislative body', 'tail': 'devolved parliament', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'devolved parliament', 'type': 'applies to jurisdiction', 'tail': 'Scotland', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'Scotland’s', 'type': 'legislative body', 'tail': 'devolved parliament', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'devolved parliament', 'type': 'applies to jurisdiction', 'tail': 'Scotland’s', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'Scotland', 'type': 'legislative body', 'tail': 'parliament', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'parliament', 'type': 'applies to jurisdiction', 'tail': 'Scotland', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3844, 3972]]}}}
#   {'head': 'North Sea oilfields', 'type': 'country', 'tail': 'United States of America', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3968, 4096]]}}}
#   {'head': 'United States of America', 'type': 'member of', 'tail': 'UN', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3968, 4096]]}}}
#   {'head': 'North Sea', 'type': 'basin country', 'tail': 'US', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3968, 4096]]}}}
#   {'head': 'US', 'type': 'located in or next to body of water', 'tail': 'North Sea', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[3968, 4096]]}}}
#   {'head': 'elected president of the US', 'type': 'candidate', 'tail': 'Joe Biden', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[4092, 4220]]}}}
#   {'head': 'Joe Biden', 'type': 'candidacy in election', 'tail': 'elected president of the US', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[4092, 4220]]}}}
#   {'head': 'elected president of the US in November 2020', 'type': 'candidate', 'tail': 'Joe Biden', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[4092, 4220]]}}}
#   {'head': 'Joe Biden', 'type': 'candidacy in election', 'tail': 'elected president of the US in November 2020', 'sentiment': 'Environmental Positive', 'meta': {'https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/': {'spans': [[4092, 4220]]}}}
# Sources:
#   ('https://www.reuters.com/article/climate-change-carbon-targets/factbox-big-oils-climate-targets-idUSL8N2HO1B4', {'article_title': "FACTBOX-Big Oil's climate targets", 'article_publish_date': datetime.datetime(2020, 11, 2, 8, 24, 58, tzinfo=tzlocal())})
#   ('https://carbontracker.org/reports/fault-lines/', {'article_title': 'Fault Lines: How diverging oil and gas company strategies link to stranded asset risk', 'article_publish_date': None})
#   ('https://www.iigcc.org/news/investor-groups-call-on-companies-to-reflect-climate-related-risks-in-financial-reporting/', {'article_title': 'Investor groups call on companies to reflect climate-related risks in financial reporting – IIGCC', 'article_publish_date': None})
#   ('https://www.unpri.org/sustainability-issues/accounting-for-climate-change', {'article_title': 'Accounting for climate change', 'article_publish_date': None})
#   ('https://www.iigcc.org/download/investor-expectations-for-paris-aligned-accounts/?wpdmdl=4001&masterkey=5fabc4d15595d', {'article_title': '', 'article_publish_date': None})
#   ('https://cdn.ifrs.org/-/media/feature/news/2019/november/in-brief-climate-change-nick-anderson.pdf?la=en', {'article_title': '', 'article_publish_date': None})
#   ('https://www.iea.org/reports/world-energy-outlook-2020/achieving-net-zero-emissions-by-2050', {'article_title': 'Achieving net-zero emissions by 2050 – World Energy Outlook 2020 – Analysis', 'article_publish_date': None})
#   ('https://www.climatechangenews.com/2019/06/14/countries-net-zero-climate-goal/', {'article_title': 'Which countries have a net zero carbon goal?', 'article_publish_date': datetime.datetime(2019, 6, 14, 0, 0)})

# %%
filename = "chev_2021_net_zero_news2.html"

# %%
save_network_html(kb, filename=filename)
IPython.display.HTML(filename=filename)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# chev_2021_net_zero_news2.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 700px;
#                  height: 700px;
#                  background-color: #eeeeee;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#              #loadingBar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width: 700px;
#                  height: 700px;
#                  background-color:rgba(200,200,200,0.8);
#                  -webkit-transition: all 0.5s ease;
#                  -moz-transition: all 0.5s ease;
#                  -ms-transition: all 0.5s ease;
#                  -o-transition: all 0.5s ease;
#                  transition: all 0.5s ease;
#                  opacity:1;
#              }
#
#              #bar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width:20px;
#                  height:20px;
#                  margin:auto auto auto auto;
#                  border-radius:11px;
#                  border:2px solid rgba(30,30,30,0.05);
#                  background: rgb(0, 173, 246); /* Old browsers */
#                  box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#              }
#
#              #border {
#                  position:absolute;
#                  top:10px;
#                  left:10px;
#                  width:500px;
#                  height:23px;
#                  margin:auto auto auto auto;
#                  box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#                  border-radius:10px;
#              }
#
#              #text {
#                  position:absolute;
#                  top:8px;
#                  left:530px;
#                  width:30px;
#                  height:50px;
#                  margin:auto auto auto auto;
#                  font-size:22px;
#                  color: #000000;
#              }
#
#              div.outerBorder {
#                  position:relative;
#                  top:400px;
#                  width:600px;
#                  height:44px;
#                  margin:auto auto auto auto;
#                  border:8px solid rgba(0,0,0,0.1);
#                  background: rgb(252,252,252); /* Old browsers */
#                  background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#                  background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#                  background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#                  background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#                  background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#                  background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#                  filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#                  border-radius:72px;
#                  box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#              }
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#             <div id="loadingBar">
#               <div class="outerBorder">
#                 <div id="text">0%</div>
#                 <div id="border">
#                   <div id="bar"></div>
#                 </div>
#               </div>
#             </div>
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#A699B0", "id": "Equinor", "label": "Equinor", "shape": "circle"}, {"color": "#A699B0", "id": "Norway", "label": "Norway", "shape": "circle"}, {"color": "#A699B0", "id": "Repsol", "label": "Repsol", "shape": "circle"}, {"color": "#A699B0", "id": "Spain", "label": "Spain", "shape": "circle"}, {"color": "#A699B0", "id": "Norway\u0027s", "label": "Norway\u0027s", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage", "label": "carbon capture and storage", "shape": "circle"}, {"color": "#A699B0", "id": "carbon", "label": "carbon", "shape": "circle"}, {"color": "#A699B0", "id": "oil", "label": "oil", "shape": "circle"}, {"color": "#A699B0", "id": "energy", "label": "energy", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage technology", "label": "carbon capture and storage technology", "shape": "circle"}, {"color": "#A699B0", "id": "ConocoP", "label": "ConocoP", "shape": "circle"}, {"color": "#A699B0", "id": "Chevron", "label": "Chevron", "shape": "circle"}, {"color": "#A699B0", "id": "methane", "label": "methane", "shape": "circle"}, {"color": "#A699B0", "id": "Exxon", "label": "Exxon", "shape": "circle"}, {"color": "#A699B0", "id": "GHG", "label": "GHG", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity", "label": "carbon intensity", "shape": "circle"}, {"color": "#A699B0", "id": "carbon intensity vs 2016", "label": "carbon intensity vs 2016", "shape": "circle"}, {"color": "#A699B0", "id": "2016", "label": "2016", "shape": "circle"}, {"color": "#A699B0", "id": "Shell", "label": "Shell", "shape": "circle"}, {"color": "#A699B0", "id": "carbon capture and storage capacity", "label": "carbon capture and storage capacity", "shape": "circle"}, {"color": "#A699B0", "id": "oil equivalent", "label": "oil equivalent", "shape": "circle"}, {"color": "#A699B0", "id": "barrels

# %%
kb.relations
# Out:
# [{'head': 'Vancouver',
#   'type': 'capital of',
#   'tail': 'British Columbia',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[0,
#       128]]}}},
#  {'head': 'British Columbia',
#   'type': 'capital',
#   'tail': 'Vancouver',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[0,
#       128]]}}},
#  {'head': 'Sustainable Development Goals',
#   'type': 'has part',
#   'tail': 'Kyoto Protocol',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[242,
#       370]]}}},
#  {'head': 'Wind',
#   'type': 'subclass of',
#   'tail': 'Renewable energy',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[363,
#       491]]}}},
#  {'head': 'Solar power',
#   'type': 'subclass of',
#   'tail': 'Renewable energy',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[363,
#       491]]}}},
#  {'head': 'Occupational safety and health',
#   'type': 'facet of',
#   'tail': 'Biophysical environment',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[605,
#       733]]}}},
#  {'head': 'Risk',
#   'type': 'facet of',
#   'tail': 'Forward-looking statement',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[1089,
#       1217]]}}},
#  {'head': 'Risk',
#   'type': 'has part',
#   'tail': 'Forward-looking statement',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[1089,
#       1217]]}}},
#  {'head': 'Flood',
#   'type': 'has effect',
#   'tail': 'Severe weather',
#   'sentiment': 'Environmental Negative',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[1331,
#       1459]]}}},
#  {'head': 'Flood',
#   'type': 'has cause',
#   'tail': 'Severe weather',
#   'sentiment': 'Environmental Negative',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[1331,
#       1459]]}}},
#  {'head': 'Severe weather',
#   'type': 'has effect',
#   'tail': 'Flood',
#   'sentiment': 'Environmental Negative',
#   'meta': {'https://finance.yahoo.com/news/equinox-gold-publishes-2022-esg-200000910.html': {'spans': [[1331,
#       1459]]}}},
#  {'head': 'Treasurer',
#   'type': 'applies to jurisdiction',
#   'tail': 'Oklahoma',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://justthenews.com/politics-policy/finance/oklahoma-blacklists-blackrock-major-banks-over-esg-practices': {'spans': [[0,
#       128]]}}},
#  {'head': 'Todd Russ',
#   'type': 'position held',
#   'tail': 'Treasurer',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://justthenews.com/politics-policy/finance/oklahoma-blacklists-blackrock-major-banks-over-esg-practices': {'spans': [[0,
#       128]]}}},
#  {'head': 'Wells Fargo',
#   'type': 'instance of',
#   'tail': 'Bank',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://justthenews.com/politics-policy/finance/oklahoma-blacklists-blackrock-major-banks-over-esg-practices': {'spans': [[127,
#       255]]}}},
#  {'head': 'JPMorgan Chase',
#   'type': 'instance of',
#   'tail': 'Bank',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://justthenews.com/politics-policy/finance/oklahoma-blacklists-blackrock-major-banks-over-esg-practices': {'spans': [[127,
#       255]]}}},
#  {'head': 'Bank of America',
#   'type': 'instance of',
#   'tail': 'Bank',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://justthenews.com/politics-policy/finance/oklahoma-blacklists-blackrock-major-banks-over-esg-practices': {'spans': [[127,
#       255]]}}},
#  {'head': 'Ron DeSantis',
#   'type': 'member of political party',
#   'tail': 'R',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[0,
#       128]]}}},
#  {'head': 'Environmental, social, and corporate governance',
#   'type': 'subclass of',
#   'tail': 'Corporatism',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[122,
#       250]]}}},
#  {'head': 'Corporatism',
#   'type': 'subclass of',
#   'tail': 'Ideology',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[122,
#       250]]}}},
#  {'head': 'Environmental, social, and corporate governance',
#   'type': 'part of',
#   'tail': 'Corporatism',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[122,
#       250]]}}},
#  {'head': 'Bank account',
#   'type': 'use',
#   'tail': 'Financial services',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[244,
#       372]]}}},
#  {'head': 'Bank account',
#   'type': 'subclass of',
#   'tail': 'Financial services',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[244,
#       372]]}}},
#  {'head': 'Bank',
#   'type': 'use',
#   'tail': 'Financial services',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[244,
#       372]]}}},
#  {'head': 'BlackRock',
#   'type': 'industry',
#   'tail': 'Investment',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[366,
#       494]]}}},
#  {'head': 'BlackRock',
#   'type': 'product or material produced',
#   'tail': 'Investment',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[366,
#       494]]}}},
#  {'head': 'Employee Retirement Income Security Act of 1974',
#   'type': 'legislated by',
#   'tail': 'Congress',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[488,
#       616]]}}},
#  {'head': 'Employee Retirement Income Security Act of 1974',
#   'type': 'main subject',
#   'tail': 'Ministry of Labour',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[488,
#       616]]}}},
#  {'head': 'Mike Braun',
#   'type': 'member of political party',
#   'tail': 'R',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.mrctv.org/blog/esg-doa-florida-desantis-does-fla-what-biden-blocked-congress-doing-everyone': {'spans': [[610,
#       738]]}}},
#  {'head': 'Government',
#   'type': 'officeholder',
#   'tail': 'Ron DeSantis',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[0,
#       128],
#      [117, 245]]},
#    'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[0,
#       128]]}}},
#  {'head': 'Ron DeSantis',
#   'type': 'position held',
#   'tail': 'Government',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[0,
#       128],
#      [117, 245]]},
#    'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[0,
#       128]]}}},
#  {'head': 'Paul Renner',
#   'type': 'position held',
#   'tail': 'Speaker (politics)',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[234,
#       362]]}}},
#  {'head': 'Speaker (politics)',
#   'type': 'officeholder',
#   'tail': 'Paul Renner',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[234,
#       362]]}}},
#  {'head': 'Veto',
#   'type': 'author',
#   'tail': 'Joe Biden',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[351,
#       479]]}}},
#  {'head': 'Veto',
#   'type': 'participant',
#   'tail': 'Joe Biden',
#   'meta': {'https://www.dailymail.co.uk/news/article-12042649/Ron-DeSantis-signs-ESG-bill-banning-public-funds-invested-social-environmental-projects.html': {'spans': [[351,
#       479]]}}},
#  {'head': 'Florida',
#   'type': 'office held by head of government',
#   'tail': 'Government',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[0,
#       128]]}}},
#  {'head': 'Government',
#   'type': 'applies to jurisdiction',
#   'tail': 'Florida',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[0,
#       128]]}}},
#  {'head': 'Florida',
#   'type': 'instance of',
#   'tail': 'Governor',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[240,
#       368]]}}},
#  {'head': 'Ministry of Labour',
#   'type': 'office held by head of the organization',
#   'tail': 'Secretary',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[360,
#       488]]}}},
#  {'head': 'Eugene Scalia',
#   'type': 'position held',
#   'tail': 'Secretary',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[360,
#       488]]}}},
#  {'head': 'Eugene Scalia',
#   'type': 'employer',
#   'tail': 'Ministry of Labour',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[360,
#       488]]}}},
#  {'head': 'Jill Fisch',
#   'type': 'employer',
#   'tail': 'University of Pennsylvania Law School',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[480,
#       608]]}}},
#  {'head': 'Jill Fisch',
#   'type': 'educated at',
#   'tail': 'University of Pennsylvania Law School',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[480,
#       608]]}}},
#  {'head': 'University of Pennsylvania Law School',
#   'type': 'field of work',
#   'tail': 'Corporate law',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[480,
#       608]]}}},
#  {'head': 'Petroleum industry',
#   'type': 'has effect',
#   'tail': 'Pollution',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[720,
#       848]]}}},
#  {'head': 'Renewable energy',
#   'type': 'subclass of',
#   'tail': 'Sustainable energy',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.investmentnews.com/floridas-new-law-makes-esg-murkier-237146': {'spans': [[840,
#       968]]}}},
#  {'head': 'Florida',
#   'type': 'office held by head of government',
#   'tail': 'Attorney general',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[875,
#       1003]]}}},
#  {'head': 'Attorney general',
#   'type': 'applies to jurisdiction',
#   'tail': 'Florida',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[875,
#       1003]]}}},
#  {'head': 'Florida',
#   'type': 'office held by head of government',
#   'tail': 'Governor',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[875,
#       1003]]}}},
#  {'head': 'Governor',
#   'type': 'applies to jurisdiction',
#   'tail': 'Florida',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[875,
#       1003]]}}},
#  {'head': 'Kentucky',
#   'type': 'owned by',
#   'tail': 'BlackRock',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[1000,
#       1128]]}}},
#  {'head': 'BlackRock',
#   'type': 'owner of',
#   'tail': 'Kentucky',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[1000,
#       1128]]}}},
#  {'head': 'Legislator',
#   'type': 'applies to jurisdiction',
#   'tail': 'Florida',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://gizmodo.com/florida-lawmakers-dont-know-what-theyre-doing-with-esg-1850400943': {'spans': [[1125,
#       1253]]}}},
#  {'head': 'Socially responsible investing',
#   'type': 'facet of',
#   'tail': 'Socially responsible investing',
#   'meta': {'https://www.marketwatch.com/story/confusion-and-outright-lies-congress-and-the-importance-of-informed-esg-policy-making-99c6b365': {'spans': [[0,
#       128]]}}},
#  {'head': 'Social',
#   'type': 'part of',
#   'tail': 'Society',
#   'sentiment': 'Environmental Positive',
#   'meta': {'https://www.marketwatch.com/story/confusion-and-outright-lies-congress-and-the-importance-of-informed-esg-policy-making-99c6b365': {'spans': [[0,
#       128]]}}},
#  {'head': 'Petroleum industry',
#   'type': 'located in the administrative territorial entity',
#   'tail': 'Oklahoma',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[112,
#       240]]}}},
#  {'head': 'Petroleum industry',
#   'type': 'location',
#   'tail': 'Oklahoma',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[112,
#       240]]}}},
#  {'head': 'BlackRock',
#   'type': 'owned by',
#   'tail': 'JPMorgan Chase',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[336,
#       464]]}}},
#  {'head': 'BlackRock',
#   'type': 'parent organization',
#   'tail': 'JPMorgan Chase',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[336,
#       464]]}}},
#  {'head': 'JPMorgan Chase',
#   'type': 'subsidiary',
#   'tail': 'BlackRock',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[336,
#       464]]}}},
#  {'head': 'Natural gas',
#   'type': 'has part',
#   'tail': 'Oil',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[448,
#       576]]}}},
#  {'head': 'Natural gas',
#   'type': 'subclass of',
#   'tail': 'Energy',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[448,
#       576]]}}},
#  {'head': 'Natural gas',
#   'type': 'different from',
#   'tail': 'Oil',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[448,
#       576]]}}},
#  {'head': 'JPMorgan Chase',
#   'type': 'instance of',
#   'tail': 'Asset management',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[560,
#       688]]}}},
#  {'head': 'Oklahoma Legislature',
#   'type': 'applies to jurisdiction',
#   'tail': 'Oklahoma',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[560,
#       688],
#      [672, 800]]}}},
#  {'head': 'Oklahoma',
#   'type': 'legislative body',
#   'tail': 'Oklahoma Legislature',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[560,
#       688],
#      [672, 800]]}}},
#  {'head': 'Asset management',
#   'type': 'subclass of',
#   'tail': 'Investment fund',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.washingtontimes.com/news/2023/may/3/oklahoma-latest-state-boot-blackrock-other-esg-lov/': {'spans': [[784,
#       912]]}}},
#  {'head': 'Dun & Bradstreet',
#   'type': 'headquarters location',
#   'tail': 'Jacksonville, Florida',
#   'meta': {'https://www.businesswire.com/news/home/20230503005979/en/Dun-Bradstreet-Expands-Its-ESG-Rankings-Coverage-to-Nearly-74-Million-Public-and-Private-Companies': {'spans': [[0,
#       128]]}}},
#  {'head': 'Dun & Bradstreet',
#   'type': 'location of formation',
#   'tail': 'Jacksonville, Florida',
#   'meta': {'https://www.businesswire.com/news/home/20230503005979/en/Dun-Bradstreet-Expands-Its-ESG-Rankings-Coverage-to-Nearly-74-Million-Public-and-Private-Companies': {'spans': [[0,
#       128]]}}},
#  {'head': 'Supply chain',
#   'type': 'facet of',
#   'tail': 'Supply chain',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.businesswire.com/news/home/20230503005979/en/Dun-Bradstreet-Expands-Its-ESG-Rankings-Coverage-to-Nearly-74-Million-Public-and-Private-Companies': {'spans': [[472,
#       600]]}}},
#  {'head': 'Dun & Bradstreet',
#   'type': 'inception',
#   'tail': '1841',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.businesswire.com/news/home/20230503005979/en/Dun-Bradstreet-Expands-Its-ESG-Rankings-Coverage-to-Nearly-74-Million-Public-and-Private-Companies': {'spans': [[708,
#       836]]}}},
#  {'head': 'Goal setting',
#   'type': 'facet of',
#   'tail': 'Strategic planning',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[123,
#       251]]}}},
#  {'head': 'Goal setting',
#   'type': 'subclass of',
#   'tail': 'Strategic planning',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[123,
#       251]]}}},
#  {'head': 'Market research',
#   'type': 'studies',
#   'tail': 'Market trend',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[738,
#       866]]}}},
#  {'head': 'Market trend',
#   'type': 'studied by',
#   'tail': 'Market research',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[738,
#       866]]}}},
#  {'head': 'North America',
#   'type': 'has part',
#   'tail': 'United States',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'North America',
#   'type': 'has part',
#   'tail': 'Canada',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'North America',
#   'type': 'has part',
#   'tail': 'Mexico',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'United States',
#   'type': 'part of',
#   'tail': 'North America',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'Canada',
#   'type': 'part of',
#   'tail': 'North America',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'Mexico',
#   'type': 'part of',
#   'tail': 'North America',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'South America',
#   'type': 'has part',
#   'tail': 'Brazil',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'Brazil',
#   'type': 'part of',
#   'tail': 'South America',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1107,
#       1235]]}}},
#  {'head': 'Middle East',
#   'type': 'continent',
#   'tail': 'Africa',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1230,
#       1358]]}}},
#  {'head': 'Egypt',
#   'type': 'part of',
#   'tail': 'Middle East',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1230,
#       1358]]}}},
#  {'head': 'Egypt',
#   'type': 'continent',
#   'tail': 'Africa',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1230,
#       1358]]}}},
#  {'head': 'Revenue',
#   'type': 'part of',
#   'tail': 'Sales',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1353,
#       1481]]}}},
#  {'head': 'North America',
#   'type': 'instance of',
#   'tail': 'Region',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1476,
#       1604]]}}},
#  {'head': 'Europe',
#   'type': 'instance of',
#   'tail': 'Region',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1476,
#       1604]]}}},
#  {'head': 'Asia',
#   'type': 'instance of',
#   'tail': 'Region',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://fylladey.com/2023/05/investor-esg-software-market-is-thriving-worldwide-diligent-corporation-greenstone-wesustain-novisto-emex-goby-inc-accuvio-inc-enhelix-workiva-vervantis-inc-enablon-north-america-corp-gen/': {'spans': [[1476,
#       1604]]}}},
#  {'head': 'Berkshire Bank',
#   'type': 'headquarters location',
#   'tail': 'Boston',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.cbia.com/news/member-news/berkshire-bank-esg-report': {'spans': [[366,
#       494]]}}},
#  {'head': 'Massachusetts',
#   'type': 'capital',
#   'tail': 'Boston',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.cbia.com/news/member-news/berkshire-bank-esg-report': {'spans': [[366,
#       494]]}}},
#  {'head': '2022',
#   'type': 'point in time',
#   'tail': '2022',
#   'sentiment': 'Environmental Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[0,
#       128]]}}},
#  {'head': 'State treasurer',
#   'type': 'applies to jurisdiction',
#   'tail': 'Utah',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[244,
#       372]]}}},
#  {'head': 'Utah',
#   'type': 'office held by head of government',
#   'tail': 'State treasurer',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[244,
#       372]]}}},
#  {'head': 'Green marketing',
#   'type': 'facet of',
#   'tail': 'Corporate social responsibility',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[488,
#       616]]}}},
#  {'head': 'Green marketing',
#   'type': 'opposite of',
#   'tail': 'Greenwashing',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[488,
#       616]]}}},
#  {'head': 'Greenwashing',
#   'type': 'opposite of',
#   'tail': 'Green marketing',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[488,
#       616]]}}},
#  {'head': 'Environmental issues',
#   'type': 'facet of',
#   'tail': 'Corporate social responsibility',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[610,
#       738]]}}},
#  {'head': 'Greenwashing',
#   'type': 'subclass of',
#   'tail': 'Sustainability reporting',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[976,
#       1104]]}}},
#  {'head': 'Pension',
#   'type': 'part of',
#   'tail': 'Public',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1220,
#       1348]]}}},
#  {'head': 'American City Business Journals',
#   'type': 'publisher',
#   'tail': 'Wharton School',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1342,
#       1470]]}}},
#  {'head': 'PwC',
#   'type': 'industry',
#   'tail': 'Audit',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1586,
#       1714]]}}},
#  {'head': 'Biophysical environment',
#   'type': 'subclass of',
#   'tail': 'Social',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1708,
#       1836]]}}},
#  {'head': 'Social',
#   'type': 'has part',
#   'tail': 'Biophysical environment',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1708,
#       1836]]}}},
#  {'head': 'Share (finance)',
#   'type': 'owned by',
#   'tail': 'Company',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1830,
#       1958]]}}},
#  {'head': 'Share (finance)',
#   'type': 'has part',
#   'tail': 'Share (finance)',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[1830,
#       1958]]}}},
#  {'head': 'Risk',
#   'type': 'studied by',
#   'tail': 'Management',
#   'meta': {'https://www.jdsupra.com/legalnews/how-are-companies-reacting-to-anti-esg-8428848/': {'spans': [[2196,
#       2324]]}}},
#  {'head': 'Environmental, social, and corporate governance',
#   'type': 'subclass of',
#   'tail': 'Risk',
#   'sentiment': 'Environmental Negative',
#   'meta': {'https://www.jdsupra.com/legalnews/the-risk-of-falling-off-the-truck-3596852/': {'spans': [[0,
#       128]]}}},
#  {'head': 'Environmental hazard',
#   'type': 'subclass of',
#   'tail': 'Adverse effect',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.jdsupra.com/legalnews/the-risk-of-falling-off-the-truck-3596852/': {'spans': [[222,
#       350]]}}},
#  {'head': 'Likelihood function',
#   'type': 'subclass of',
#   'tail': 'Probability',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.jdsupra.com/legalnews/the-risk-of-falling-off-the-truck-3596852/': {'spans': [[333,
#       461]]}}},
#  {'head': 'Florida',
#   'type': 'legislative body',
#   'tail': 'Legislature',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[0,
#       128]]}}},
#  {'head': 'Legislature',
#   'type': 'applies to jurisdiction',
#   'tail': 'Florida',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[0,
#       128]]}}},
#  {'head': 'Florida Legislature',
#   'type': 'has part',
#   'tail': 'House',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[126,
#       254]]}}},
#  {'head': 'House',
#   'type': 'part of',
#   'tail': 'Florida Legislature',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[126,
#       254]]}}},
#  {'head': 'Credit rating',
#   'type': 'instance of',
#   'tail': 'Credit rating agency',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[252,
#       380]]}}},
#  {'head': 'Credit risk',
#   'type': 'instance of',
#   'tail': 'Credit rating',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[378,
#       506]]}}},
#  {'head': 'Credit rating',
#   'type': 'facet of',
#   'tail': 'Credit risk',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[378,
#       506]]}}},
#  {'head': 'Credit risk',
#   'type': 'has part',
#   'tail': 'Credit rating',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[378,
#       506]]}}},
#  {'head': 'Bank account',
#   'type': 'use',
#   'tail': 'Credit',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[882,
#       1010]]}}},
#  {'head': 'Bank account',
#   'type': 'uses',
#   'tail': 'Credit',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[882,
#       1010]]}}},
#  {'head': 'Capitalism',
#   'type': 'opposite of',
#   'tail': 'Democracy',
#   'sentiment': 'Governance Neutral',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[1260,
#       1388]]}}},
#  {'head': 'Mike Frerichs',
#   'type': 'position held',
#   'tail': 'Illinois Treasurer',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[1764,
#       1892]]}}},
#  {'head': 'Kestrel',
#   'type': 'headquarters location',
#   'tail': 'Oregon',
#   'sentiment': 'Governance Positive',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[2016,
#       2144]]}}},
#  {'head': '2021',
#   'type': 'point in time',
#   'tail': '2021',
#   'sentiment': 'Governance Negative',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[2142,
#       2270]]}}},
#  {'head': 'Florida',
#   'type': 'capital',
#   'tail': 'Miami',
#   'meta': {'https://www.bondbuyer.com/news/florida-bans-issuance-of-municipal-bonds-using-esg-precepts': {'spans': [[2268,
#       2396]]}}}]
